# %%
import pandas as pd

# %%
bb = pd.read_csv('Hot Stuff.csv')

# %%
bb = bb.sort_values(['WeekID', 'Week Position'], ascending = True)

# %%
bb
# Out:
#                                                       url    WeekID  \
# 64198   http://www.billboard.com/charts/hot-100/1966-0...  1/1/1966
# 297456  http://www.billboard.com/charts/hot-100/1966-0...  1/1/1966
# 191006  http://www.billboard.com/charts/hot-100/1966-0...  1/1/1966
# 202297  http://www.billboard.com/charts/hot-100/1966-0...  1/1/1966
# 291425  http://www.billboard.com/charts/hot-100/1966-0...  1/1/1966
# ...                                                   ...       ...
# 205309  http://www.billboard.com/charts/hot-100/2017-0...  9/9/2017
# 17965   http://www.billboard.com/charts/hot-100/2017-0...  9/9/2017
# 78808   http://www.billboard.com/charts/hot-100/2017-0...  9/9/2017
# 314469  http://www.billboard.com/charts/hot-100/2017-0...  9/9/2017
# 125867  http://www.billboard.com/charts/hot-100/2017-0...  9/9/2017
#
#         Week Position                                               Song  \
# 64198               1                               The Sound Of Silence
# ...

# %%
bb = bb.drop('url', axis = 1)
bb
# Out:
#           WeekID  Week Position  \
# 64198   1/1/1966              1
# 297456  1/1/1966              2
# 191006  1/1/1966              3
# 202297  1/1/1966              4
# 291425  1/1/1966              5
# ...          ...            ...
# 205309  9/9/2017             96
# 17965   9/9/2017             97
# 78808   9/9/2017             98
# 314469  9/9/2017             99
# 125867  9/9/2017            100
#
#                                                      Song  \
# 64198                                The Sound Of Silence
# 297456                                 We Can Work It Out
# 191006                            I Got You (I Feel Good)
# 202297  Turn! Turn! Turn! (To Everything There Is A Se...
# 291425                                      Over And Over
# ...                                                   ...
# 205309                                        Untouchable
# 17965                                             Privacy
# ...

# %%
bb = bb[bb['Week Position'] == 1]

# %%
bb
# Out:
#           WeekID  Week Position                                         Song  \
# 64198   1/1/1966              1                         The Sound Of Silence
# 145617  1/1/1972              1                                Brand New Key
# 197732  1/1/1977              1       Tonight's The Night (Gonna Be Alright)
# 265420  1/1/1983              1                                     Maneater
# 260332  1/1/1994              1                                         Hero
# ...          ...            ...                                          ...
# 239147  9/9/1989              1                                Hangin' Tough
# 176688  9/9/1995              1  Gangsta's Paradise (From "Dangerous Minds")
# 58225   9/9/2000              1                        Doesn't Really Matter
# 291097  9/9/2006              1                                     SexyBack
# 76844   9/9/2017              1                                    Despacito
#
# ...

# %%
bb.reset_index()
# Out:
#        index    WeekID  Week Position  \
# 0      64198  1/1/1966              1
# 1     145617  1/1/1972              1
# 2     197732  1/1/1977              1
# 3     265420  1/1/1983              1
# 4     260332  1/1/1994              1
# ...      ...       ...            ...
# 3200  239147  9/9/1989              1
# 3201  176688  9/9/1995              1
# 3202   58225  9/9/2000              1
# 3203  291097  9/9/2006              1
# 3204   76844  9/9/2017              1
#
#                                              Song  \
# 0                            The Sound Of Silence
# 1                                   Brand New Key
# 2          Tonight's The Night (Gonna Be Alright)
# 3                                        Maneater
# 4                                            Hero
# ...                                           ...
# 3200                                Hangin' Tough
# 3201  Gangsta's Paradise (From "Dangerous Minds")
# ...
