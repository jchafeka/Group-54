# %% [markdown]
# # COGS 108 - Final Project
#
# ## Permissions
# [ ] YES - make available
# [ ] NO - keep private
#
# ## Overview
# Fill in your overview here
#
# ## Names
# Martyna Marcinkowska
# Alyssa Goebel
# Sachiko Brown
# Janhavi Chafekar
# Haley Rezendes
#
# ## Group Members IDs
# A16140394
# A13296387
# A15631683
# A15109120
# A14597775

# %% [markdown]
# ## Research Question

# %% [markdown]
# How does presidential approval rating correlate with consumer and government expenditure? Specifically, how does presidential approval rating correlate with sales of cars, sales of clothes, restaurant sales, and government social benefits to persons?

# %% [markdown]
# ## Background & Prior Work ##

# %% [markdown]
# It’s worthwhile to note that presidential approval ratings can be affected by a variety of factors including current events, political orientation, and overall job performance. With this said, there seems to be a slight indication of decline in presidential approval ratings since 1990 (Gallup, 2019). Our team collaborated to decide which categories of spending would create a well-rounded picture of non-essential spending by consumers. We concluded that purchases of cars, clothing, and restaurant food would accurately describe a majority of this spending.
#
# References
#
# 1.
#
# 2.

# %% [markdown]
# ## Hypothesis ##

# %% [markdown]
# We hypothesize that more spending (or in particular, consumers having more money to spend and things to spend money on) would be correlated with more perceived job approval of the president. When people have money in their pocket to spend on non-essentials like cars or clothing, they feel less stressed, and happier overall. Thus, they feel like things are generally going well in their life, and their country. This could co-occur with them being more satisfied, or approving, of the country's leader: in the US case, the president. In addition, people love receiving money, so the more social benefits that the government is handing out, the more people will approve of the president. If this hypothesis is true, we can guess that President Trump is currently on the upward swing of approval ratings due to the stimulus checks that have been distributed in the time of COVID-19.

# %% [markdown]
# ## Data ##

# %% [markdown]
# Our spending data originates with the Federal Reserve Bank of St. Louis which tracks tons of economical data for the United States including interest rates, unemployment, GDP and more. [Details about first datasets here]

# %% [markdown]
# ## Dataset(s)
#
# Dataset Name: American Presidency Project - Approval Ratings
#
# Link to the dataset: https://docs.google.com/spreadsheets/d/1iEl565M1mICTubTtoxXMdxzaHzAcPTnb3kpRndsrfyY/edit?usp=sharing
#
# Number of observations: 380
#
# Our presidential approval data comes from the American Presidency Project from University of California Santa Barbara. This project is non-profit and non-partisan, so it is likely the most objective source we can find. Their website says that they consider themselves, "the source of presidential documents on the internet" and boasts over 130,000 documents. The dataset we pulled lists surveys taken roughly biweekly for more recent presidents. We cleaned this data to compile ratings by month to standardize across the presidents we are examining. We included in our final dataset Donald Trump, Barack Obama, George W. Bush, Bill Clinton, and George H.W. Bush, so our data set tracks monthly presidential approval data from April 2020 back to January 1989.
#
# Dataset Name:
# Link to the dataset:
# Number of observations:
# 1-2 sentences describing each dataset.
#
# Dataset Name:
# Link to the dataset:
# Number of observations:
# 1-2 sentences describing each dataset.
#
# Dataset Name:
# Link to the dataset:
# Number of observations:
# 1-2 sentences describing each dataset.
#
# Dataset Name:
# Link to the dataset:
# Number of observations:
# 1-2 sentences describing each dataset.

# %% [markdown]
# ## Setup

# %%
from PIL import Image
img = Image.open('Screen Shot 2020-05-28 at 1.38.09 PM.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1133x368 at 0x7FBD343D3630>

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ## Data Analysis & Results

# %% [markdown]
# ## Ethics & Privacy

# %% [markdown]
# ## Conclusion & Discussion

# %% [markdown]
# ## Team Contributions
