# %%
import pandas as pd

# %%
bb = pd.read_csv('Hot Stuff.csv')
bb
# Out:
#                                                       url      WeekID  \
# 0       http://www.billboard.com/charts/hot-100/1958-0...    8/2/1958
# 1       http://www.billboard.com/charts/hot-100/1995-1...   12/2/1995
# 2       http://www.billboard.com/charts/hot-100/1997-1...  10/11/1997
# 3       http://www.billboard.com/charts/hot-100/2006-0...    7/1/2006
# 4       http://www.billboard.com/charts/hot-100/2009-1...  10/24/2009
# ...                                                   ...         ...
# 320490  https://www.billboard.com/charts/hot-100/2019-...    1/5/2019
# 320491  https://www.billboard.com/charts/hot-100/2019-...   12/7/2019
# 320492  https://www.billboard.com/charts/hot-100/2019-...  12/14/2019
# 320493  https://www.billboard.com/charts/hot-100/2019-...  12/21/2019
# 320494  https://www.billboard.com/charts/hot-100/2019-...  12/28/2019
#
#         Week Position                                               Song  \
# ...

# %%
bb.sort_values('WeekID', ascending = False)
# Out:
#                                                       url    WeekID  \
# 17965   http://www.billboard.com/charts/hot-100/2017-0...  9/9/2017
# 184454  http://www.billboard.com/charts/hot-100/2017-0...  9/9/2017
# 216046  http://www.billboard.com/charts/hot-100/2017-0...  9/9/2017
# 286213  http://www.billboard.com/charts/hot-100/2017-0...  9/9/2017
# 61290   http://www.billboard.com/charts/hot-100/2017-0...  9/9/2017
# ...                                                   ...       ...
# 253727  http://www.billboard.com/charts/hot-100/1966-0...  1/1/1966
# 44996   http://www.billboard.com/charts/hot-100/1966-0...  1/1/1966
# 105247  http://www.billboard.com/charts/hot-100/1966-0...  1/1/1966
# 305364  http://www.billboard.com/charts/hot-100/1966-0...  1/1/1966
# 32414   http://www.billboard.com/charts/hot-100/1966-0...  1/1/1966
#
#         Week Position                                      Song  \
# 17965              97                                   Privacy
# ...
